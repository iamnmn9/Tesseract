# %%
# !sudo apt install tesseract-ocr

# %%
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from google.colab import files

uploaded = files.upload()

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/prepare-edit-and-proofread-legal-documents-and-papers.png'))

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/prepare-edit-and-proofread-legal-documents-and-papers.png'))

# %%
print(extractedInformation)
# Out:
# IN THE FEDERAL HIGH COURT
#
#
#
# BETWEEN
#
# MRS. LAWRENCE PLAINTIFF /APPLICANT
# AND
#
# MR. OPEYEMI DEFENDANT/RESPONDENT
#
# MOTION ON NOTICE
# BROUGHT PURSUANT TO ORDER 26 RULE 1 & 3, ORDER 6 RULE 5 OF THE
# FEDERAL HIGH COURT (CIVIL PROCEDURE) RULES, 2009 AND THE
# INHERENT JURISDICTION OF THE HONOURABLE COURT
#
#
#
# TAKE NOTICE that this honourable court will be moved onthe day of
# 2019 at the hour of 9 O'clock in the forenoon or so soon thereafter as Counsel may
# be heard in an application on behalf of the Defendant/Applicant for the following
# orders:
#
# 1. An order for leave of this honourable court to serve the Writ of
# Summons, Statement of Claim and all other processes in this matter by
# substituted means by serving same on the Defendant/Respondent
# through DHL or FedEx Courier Services.
#
# 2. An order deeming the said service of the originating processes as good
# and proper service.
#
# ...

# %%
import cv2

# %%
img = cv2.imread('/content/prepare-edit-and-proofread-legal-documents-and-papers.png')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=680x962 at 0x7F9843F6E190>

# %%
import numpy as np

# %%
kernel = np.ones((2, 12), np.uint8)

# %%
img3  = cv2.erode(img,kernel)

# %%
import cv2
import numpy as np
# img = cv2.imread('C.png'
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 160, 255, cv2.THRESH_BINARY)[1]
kernel = np.ones((5,5),np.uint8)
kernel2 = np.ones((3,3),np.uint8)
marker = cv2.dilate(thresh,kernel,iterations = 1)
mask=cv2.erode(thresh,kernel,iterations = 1)

while True:
    tmp=marker.copy()
    marker=cv2.erode(marker, kernel2)
    marker=cv2.max(mask, marker)
    difference = cv2.subtract(tmp, marker)
    if cv2.countNonZero(difference) == 0:
        break

marker_color = cv2.cvtColor(marker, cv2.COLOR_GRAY2BGR)
out=cv2.bitwise_or(img, marker_color)
cv2.imwrite('unbolded.png', out)
cv2_imshow(out)
# Out:
# <PIL.Image.Image image mode=RGB size=680x962 at 0x7F9843F60B10>

# %%
extractedInformation = pytesseract.image_to_string(Image.open('unbolded.png'))

# %%
print(extractedInformation)
# Out:
# IN THE FEDERAL HIGH COURT
#
#
#
# BETWEEN
#
# MRS. LAWRENCE PLAINTIFF /APPLICANT
# AND
#
# MR. OPEYEMI DEFENDANT/RESPONDENT
#
# MOTION ON NOTICE
# BROUGHT PURSUANT TO ORDER 26 RULE 1 & 3, ORDER 6 RULE 5 OF THE
#
# FEDERAL HIGH COURT (CIVIL PROCEDURE) RULES, 2009 AND THE
# INHERENT JURISDICTION OF THE HONOURABLE COURT
#
#
#
# TAKE NOTICE
#
# AND
#
# GROUNDS FOR THE APPLICATION
